# %% [markdown]
# # Laboratorio de Espectrometría con centelleador de CsI y Fotomultiplicador de Silicio (SiPM)

# %% [markdown]
# Primero cargamos todas las librerias y los datos:

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.
